# %%
# import sys
# sys.path.append(r"C:\Users\user\anaconda3\lib\site-packages\matlabengine-24.2-py3.12.egg")

# import matlab.engine
# eng = matlab.engine.start_matlab()
# print("MATLAB 연결 성공!")

# %%
# !pip install "stable-baselines3[extra]" gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\users\user\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: stable-baselines3[extra] in c:\users\user\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.7.0)
# Requirement already satisfied: cloudpickle in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.10.1)
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.66.5)
# Requirement already satisfied: rich in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3[extra]) (10.4.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# DEPRECATION: Loading egg at c:\users\user\anaconda3\lib\site-packages\matlabengine-24.2-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import numpy as np
from gymnasium import Env
from gymnasium.spaces import Box
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
import math

# --- 시뮬레이터 함수 (run_uav_sim.m 포팅 버전) ---
def run_uav_sim(Kp, Ki, Kd, dt=0.01, tf=10.0):
    n = int(tf / dt)
    m, g = 13.5, 9.81
    Ix, Iy, Iz, Ixz = 0.8244, 1.135, 1.759, 0.1204
    S, c, rho, S_p, C_p, k_m = 0.55, 0.18994, 1.2682, 0.2027, 1.0, 80
    deg2rad = np.pi / 180
    the_d = 3 * deg2rad
    limit_e = 20 * deg2rad
    noise_std = 0.1 * deg2rad

    state = np.zeros(12)
    state[2] = -100
    state[4] = 3 * deg2rad
    state[6] = 20
    state[8] = 0.1
    state[10] = 0.01

    err_int = 0
    err_prev = 0
    EA_log = []

    for _ in range(n):
        theta = state[4]
        u, w = state[6], state[8]
        q = state[10]
        err = -the_d + theta
        err_int += err * dt
        err_dev = (err - err_prev) / dt
        err_prev = err

        delta_e = np.clip(Kp * err + Ki * err_int + Kd * err_dev, -limit_e, limit_e)
        V = np.linalg.norm([u, w])
        if V < 0.1 or np.isnan(V) or np.isnan(err_int):
            return -1e6

        alpha = np.arctan2(w, u)
        q_bar = 0.5 * rho * V ** 2
        CL = 0.28 + 3.45 * alpha + 0.36 * delta_e
        CD = 0.03 + 0.3 * abs(alpha)
        Cm = -0.02338 - 0.38 * alpha - 3.6 * (c / (2 * V)) * q - 0.5 * delta_e

        Fx = -q_bar * S * CD
        Fz = -q_bar * S * CL
        F_g = np.array([-m * g * np.sin(theta), m * g * np.cos(theta), 0])
        F_a = np.array([Fx, 0, Fz])
        F_p = np.array([0.5 * rho * S_p * C_p * ((k_m * 0.4)**2 - V**2), 0, 0])

        Cw2b = np.array([[np.cos(alpha), 0, np.sin(alpha)],
                         [0, 1, 0],
                         [-np.sin(alpha), 0, np.cos(alpha)]])
        F_tot = Cw2b @ F_a + F_p + F_g
        M = q_bar * S * c * Cm
        M_a = np.array([0, M, 0])

        state = rk4_step(state, F_tot, M_a, dt, m, Ix, Iy, Iz, Ixz)
        state[10] += noise_std * np.random.randn()
        EA_log.append(state[4])

    e = the_d - np.array(EA_log)
    ISE = np.sum(e ** 2) * dt
    return -ISE


def rk4_step(state, F, M, dt, m, Ix, Iy, Iz, Ixz):
    def dynamics(s):
        return state_derivative(s, F, M, m, Ix, Iy, Iz, Ixz)
    k1 = dynamics(state)
    k2 = dynamics(state + 0.5 * dt * k1)
    k3 = dynamics(state + 0.5 * dt * k2)
    k4 = dynamics(state + dt * k3)
    return state + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)


def state_derivative(state, F, M, m, Ix, Iy, Iz, Ixz):
    phi, the, psi = state[3], state[4], state[5]
    u, v, w = state[6:9]
    p, q, r = state[9:12]

    s_phi, c_phi = np.sin(phi), np.cos(phi)
    s_the, c_the = np.sin(the), np.cos(the)
    s_psi, c_psi = np.sin(psi), np.cos(psi)

    udot = - (q * w - r * v) + F[0] / m
    vdot = - (r * u - p * w) + F[1] / m
    wdot = - (p * v - q * u) + F[2] / m

    G5 = (Iz - Ix) / Iy
    G6 = Ixz / Iy
    pdot = 0
    qdot = G5 * p * r - G6 * (p**2 - r**2) + M[1] / Iy
    rdot = 0

    Cb2n = np.array([
        [c_psi * c_the, c_psi * s_the * s_phi - s_psi * c_phi, c_psi * s_the * c_phi + s_psi * s_phi],
        [s_psi * c_the, s_psi * s_the * s_phi + c_psi * c_phi, s_psi * s_the * c_phi - c_psi * s_phi],
        [-s_the, c_the * s_phi, c_the * c_phi]
    ])
    Pos_dot = Cb2n @ np.array([u, v, w])
    phidot = 0
    thedot = c_phi * q - s_phi * r
    psidot = 0

    return np.concatenate([Pos_dot, [phidot, thedot, psidot, udot, vdot, wdot, pdot, qdot, rdot]])

# --- 강화학습 환경 정의 ---
class PIDEnv(Env):
    def __init__(self):
        super().__init__()
        self.action_space = Box(low=np.array([0.1, 0.01, 0.01], dtype=np.float32),
                                high=np.array([5.0, 2.0, 2.0], dtype=np.float32),
                                dtype=np.float32)
        self.observation_space = Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32)
        self.state = np.array([0.0], dtype=np.float32)

    def step(self, action):
        Kp, Ki, Kd = float(action[0]), float(action[1]), float(action[2])
        try:
            reward = run_uav_sim(Kp, Ki, Kd)
            if math.isnan(reward) or math.isinf(reward):
                print(f"[❌ NaN 보상] Kp={Kp:.3f}, Ki={Ki:.3f}, Kd={Kd:.3f}")
                reward = -1e6
        except Exception as e:
            print(f"[Python 시뮬 오류 발생]: {e}")
            reward = -1e6
        terminated = True
        truncated = False
        return self.state, reward, terminated, truncated, {}

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.array([0.0], dtype=np.float32)
        return self.state, {}

    def render(self, mode='human'):
        pass

# --- 학습 및 결과 출력 ---
env = PIDEnv()
check_env(env, warn=True)

model = PPO("MlpPolicy", env, verbose=1, device="cpu")  # CPU 권장
model.learn(total_timesteps=30000)

obs, _ = env.reset()
Kp, Ki, Kd = model.predict(obs, deterministic=True)[0]
print(f"🔧 최적 튜닝 결과: Kp = {Kp:.3f}, Ki = {Ki:.3f}, Kd = {Kd:.3f}")
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\stable_baselines3\common\env_checker.py:462: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.0222  |
# | time/              |          |
# |    fps             | 19       |
# |    iterations      | 1        |
# |    time_elapsed    | 105      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.0131     |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 2           |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.038057994 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0794     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.08       |
# |    std                  | 1.01        |
# |    value_loss           | 0.000718    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.0124     |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 3           |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.044231106 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.107      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.082      |
# |    std                  | 0.989       |
# |    value_loss           | 0.00056     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.01       |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 4           |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.041490972 |
# |    clip_fraction        | 0.446       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0616     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0735     |
# |    std                  | 0.966       |
# |    value_loss           | 0.000399    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.00514   |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 5          |
# |    time_elapsed         | 538        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.04162872 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0718    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.069     |
# |    std                  | 0.94       |
# |    value_loss           | 0.000262   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.00233    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 6           |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.041534908 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0729     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0628     |
# |    std                  | 0.915       |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.00121    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 7           |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.039427646 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0565     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0617     |
# |    std                  | 0.886       |
# |    value_loss           | 0.000106    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.00187   |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 8          |
# |    time_elapsed         | 860        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.03860706 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.79      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0734    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0658    |
# |    std                  | 0.856      |
# |    value_loss           | 4.17e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.000645   |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 9           |
# |    time_elapsed         | 968         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.034613274 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0392     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.065      |
# |    std                  | 0.822       |
# |    value_loss           | 2.73e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.000484   |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 10          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.052433617 |
# |    clip_fraction        | 0.49        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.115      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0857     |
# |    std                  | 0.776       |
# |    value_loss           | 5.04e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.000295   |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 11          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.057305485 |
# |    clip_fraction        | 0.512       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.105      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0911     |
# |    std                  | 0.728       |
# |    value_loss           | 6.53e-07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.00022   |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 12         |
# |    time_elapsed         | 1291       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.05987454 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.123     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0986    |
# |    std                  | 0.679      |
# |    value_loss           | 9.26e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.000173  |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 13         |
# |    time_elapsed         | 1398       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.05829725 |
# |    clip_fraction        | 0.516      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.92      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.124     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 0.632      |
# |    value_loss           | 6.19e-08   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.000128  |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 14         |
# |    time_elapsed         | 1506       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.06264949 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.127     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.591      |
# |    value_loss           | 2.45e-08   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.000125  |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 15         |
# |    time_elapsed         | 1614       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.06434245 |
# |    clip_fraction        | 0.54       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.52      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.117     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.554      |
# |    value_loss           | 8.01e-09   |
# ----------------------------------------
# 🔧 최적 튜닝 결과: Kp = 2.330, Ki = 1.581, Kd = 1.573
